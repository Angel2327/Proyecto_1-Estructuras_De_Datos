# %% [markdown]
# <a href="https://colab.research.google.com/github/Angel2327/Proyecto_1-Estructuras_De_Datos/blob/main/Proyecto_1_Imagenes_Vacas_Sanas_y_Enfermas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
-VACAS ENFERMAS-

# %%
-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
from google.colab import files
uploades = files.upload()
# Out:
#      <input type="file" id="files-26d0546f-f1ea-4c00-a9da-7fa2d27d4d64" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-26d0546f-f1ea-4c00-a9da-7fa2d27d4d64">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Vaca_Enferma_1.csv to Vaca_Enferma_1 (2).csv

# %%
dfe1 = pd.read_csv("Vaca_Enferma_1 (2).csv", sep=',')

# %%
mve1 = np.matrix(dfe1)

# %%
plt.gray()
plt.imshow(mve1)

# %%
cmve1 = mve1.compress([False, True, True],  axis=0)

# %%
plt.gray()
plt.imshow(cmve1)

# %%
-----------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
from google.colab import files
uploades = files.upload()
# Out:
#      <input type="file" id="files-ecef3681-8e09-4532-a7d6-5d016741a28c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ecef3681-8e09-4532-a7d6-5d016741a28c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Vaca_Enferma_2.csv to Vaca_Enferma_2 (1).csv

# %%
dfe2 = pd.read_csv("Vaca_Enferma_2 (1).csv", sep=',')

# %%
mve2 = np.matrix(dfe2)

# %%
plt.gray()
plt.imshow(mve2)

# %%
cmve2 = mve2.compress([False, True, True],  axis=0)

# %%
plt.gray()
plt.imshow(cmve2)

# %%
-----------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
from google.colab import files
uploades = files.upload()
# Out:
#      <input type="file" id="files-bb08f73e-0830-4c40-8424-7f85cd0db42d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bb08f73e-0830-4c40-8424-7f85cd0db42d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Vaca_Enferma_3.csv to Vaca_Enferma_3 (2).csv

# %%
dfe3 = pd.read_csv("Vaca_Enferma_3 (2).csv", sep=',')

# %%
mve3 = np.matrix(dfe3)

# %%
plt.gray()
plt.imshow(mve3)

# %%
cmve3 = mve3.compress([False, True, True], axis=0)

# %%
plt.gray()
plt.imshow(cmve3)

# %%
-----------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
from google.colab import files
uploades = files.upload()
# Out:
#      <input type="file" id="files-cd8ae1f9-403e-4c8d-becb-184609ae0f7a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cd8ae1f9-403e-4c8d-becb-184609ae0f7a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Vaca_Enferma_4.csv to Vaca_Enferma_4 (1).csv

# %%
dfe4 = pd.read_csv("Vaca_Enferma_4 (1).csv", sep=',')

# %%
mve4 = np.matrix(dfe4)

# %%
plt.gray()
plt.imshow(mve4)

# %%
cmve4 = mve4.compress([False, True, True], axis=0)

# %%
plt.gray()
plt.imshow(cmve4)

# %%
-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
from google.colab import files
uploades = files.upload()
# Out:
#      <input type="file" id="files-5850164b-eeff-4923-8b6c-bd7b7e961bef" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5850164b-eeff-4923-8b6c-bd7b7e961bef">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Vaca_Enferma_5.csv to Vaca_Enferma_5 (1).csv

# %%
dfe5 = pd.read_csv("Vaca_Enferma_5 (1).csv", sep=',')

# %%
mve5 = np.matrix(dfe5)

# %%
plt.gray()
plt.imshow(mve5)

# %%
cmve5 = mve5.compress([False, True, True], axis=0)

# %%
plt.gray()
plt.imshow(cmve5)

# %%
-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
-VACAS SANAS-

# %%
-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
from google.colab import files
uploades = files.upload()
# Out:
#      <input type="file" id="files-6f0bf0b4-207b-415f-83e8-3a02601a7f65" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6f0bf0b4-207b-415f-83e8-3a02601a7f65">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Vaca_Sana_1.csv to Vaca_Sana_1 (1).csv

# %%
dfs1 = pd.read_csv("Vaca_Sana_1 (1).csv", sep=',')

# %%
mvs1 = np.matrix(dfs1)

# %%
plt.gray()
plt.imshow(mvs1)

# %%
cmvs1 = mvs1.compress([False, True, True], axis=0)

# %%
plt.gray()
plt.imshow(cmvs1)

# %%
-----------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
from google.colab import files
uploades = files.upload()
# Out:
#      <input type="file" id="files-ed99950d-4850-4102-8a23-983946bf5054" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ed99950d-4850-4102-8a23-983946bf5054">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Vaca_Sana_2.csv to Vaca_Sana_2 (1).csv

# %%
dfs2 = pd.read_csv("Vaca_Sana_2 (1).csv", sep=',')

# %%
mvs2 = np.matrix(dfs2)

# %%
plt.gray()
plt.imshow(mvs2)

# %%
cmvs2 = mvs2.compress([False, True, True], axis=0)

# %%
plt.gray()
plt.imshow(cmvs2)

# %%
-----------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
from google.colab import files
uploades = files.upload()
# Out:
#      <input type="file" id="files-d19d375e-d192-496d-903e-2118d6fed944" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d19d375e-d192-496d-903e-2118d6fed944">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Vaca_Sana_3.csv to Vaca_Sana_3 (1).csv

# %%
dfs3 = pd.read_csv("Vaca_Sana_3 (1).csv", sep=',')

# %%
mvs3 = np.matrix(dfs3)

# %%
plt.gray()
plt.imshow(mvs3)

# %%
cmvs3 = mvs3.compress([False, True, True], axis=0)

# %%
plt.gray()
plt.imshow(cmvs3)

# %%
-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
from google.colab import files
uploades = files.upload()
# Out:
#      <input type="file" id="files-772e6ad6-7ba5-425f-9919-b717949088e1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-772e6ad6-7ba5-425f-9919-b717949088e1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Vaca_Sana_4.csv to Vaca_Sana_4 (1).csv

# %%
dfs4 = pd.read_csv("Vaca_Sana_4 (1).csv", sep=',')

# %%
mvs4 = np.matrix(dfs4)

# %%
plt.gray()
plt.imshow(mvs4)

# %%
cmvs4 = mvs4.compress([False, True, True], axis=0)

# %%
plt.gray()
plt.imshow(cmvs4)

# %%
-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
from google.colab import files
uploades = files.upload()
# Out:
#      <input type="file" id="files-37da9ad6-1a2a-4b24-8ae7-aca2bd548161" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-37da9ad6-1a2a-4b24-8ae7-aca2bd548161">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Vaca_Sana_5.csv to Vaca_Sana_5 (1).csv

# %%
dfs5 = pd.read_csv("Vaca_Sana_5 (1).csv", sep=',')

# %%
mvs5 = np.matrix(dfs5)

# %%
plt.gray()
plt.imshow(mvs5)

# %%
cmvs5 = mvs5.compress([False, True, True], axis=0)

# %%
plt.gray()
plt.imshow(cmvs5)

# %%
-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
